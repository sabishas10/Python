# %% [markdown]
# # IIT Python Class

# %% [markdown]
# ## Week 1 Homework

# %% [markdown]
# ### Print

# %% [markdown]
# Very first command: print

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
Print("Hello World!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Print("Hello World!")
#
# NameError: name 'Print' is not defined

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print("My name is Sabisha,")
print("I am an undergraduate in University of Colombo School of COmputing,")
print("I am currently learning Python Programming,")
print("I have learnt Java, and C.")
# Out:
# My name is Sabisha,
# I am an undergraduate in University of Colombo School of COmputing,
# I am currently learning Python Programming,
# I have learnt Java, and C.
