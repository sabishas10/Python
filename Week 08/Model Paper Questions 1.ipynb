# %%
#1
num1=int(input("Enter a number:"))
num2=int(input("Enter another number:"))
while num2==0:
    print("Zero division error")
    num1=int(input("Enter a number:"))
    num2=int(input("Enter another number:"))
print("Sum:",num1+num2)
print("Difference",num1-num2)
print("Multiplication:",num1*num2)
print("Division:",num1/num2)

#2
celsius=int(input("Enter the temperature in Celsius:"))
# °F = (°C x 1.8) + 32
fahrenheit=(celsius*1.8)+32
print("Temperature in fahrenheit:",fahrenheit)

#3
r=int(input("Enter the radius of the circled:"))
area=3.14*(r**2)
circumference=2*3.14*r
print("Area:",area)
print("Circumference:",circumference)

#4
num=int(input("Enter a number:"))
if num%2==0:
    print(num,"is an even number")
else:
    print(num,"is an odd number")

#5
my_str=input("Enter a sentence:")
print("Length of the sentance is:",len(my_str))
# Out:
# Enter a number: 5
# Enter another number: 0
# Zero division error
# Enter a number: 5
# Enter another number: 0
# Zero division error
# Enter a number: 5
# Enter another number: 2
# Sum: 7
# Difference 3
# Multiplication: 10
# Division: 2.5
# Enter the temperature in Celsius: 32
# Temperature in fahrenheit: 89.6
# Enter the radius of the circled: 7
# Area: 153.86
# Circumference: 43.96
# Enter a number: 1234567890
# 1234567890 is a even number
# Enter a sentence: Hello
# Length of the sentance is: 5
