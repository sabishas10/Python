# %% [markdown]
# # Week 2

# %% [markdown]
# ## Variable Declaration and Verification

# %%
x=10
y="Sri Lanka"
z=75.89
print(x)
print(y)
print(z)
# Out:
# 10
# Sri Lanka
# 75.89

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# Variable Names are Case-Sensitive
ABC=100
abc=30
a1=67
_abc=49
print(ABC)
print(abc)
print(a1)
print(_abc)
# Out:
# 100
# 30
# 67
# 49

# %%
x=10
print(x)
x="Hello World!" # Variable type can be changed even after declaration
print(x)
# Out:
# 10
# Hello World!

# %% [markdown]
# ## Arithmetic Operators

# %%
5+2
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %% [markdown]
# ## Assignment Operators

# %%
a=5
b=2
a=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a+=b
print(a)
# Out:
# 7

# %%
a=5
b=2
a-=b
print(a)
# Out:
# 3

# %%
a=5
b=2
a*=b
print(a)
# Out:
# 10

# %%
a=5
b=2
a/=b
print(a)
# Out:
# 2.5

# %%
a=5
b=2
a//=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a%=b
print(a)
# Out:
# 1

# %%
a=5
b=2
a**=b
print(a)
# Out:
# 25

# %%
a=5
b=2
a==b
# Out:
# False

# %%
a=5
b=2
a!=b
# Out:
# True

# %%
a=5
b=2
a>b
# Out:
# True

# %%
a=5
b=2
a<b
# Out:
# False

# %%
a=5
b=2
a>=b
# Out:
# True

# %%
a=5
b=2
a<=b
# Out:
# False

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# ### AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
5>7 and 5>3
# Out:
# False

# %% [markdown]
# ### OR

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5>7 or 5>3
# Out:
# True

# %% [markdown]
# ### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 7>5
# Out:
# False

# %% [markdown]
# ## User Input

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
sum=num1+num2
print(sum)
# Out:
# Enter first number: 3
# Enter second number: 6
# 9

# %%
first_name=input("Enter the First Name:")
last_name=input("Enter the Last Name:")
sub1=int(input("Enter the Subject 1 marks:"))
sub2=int(input("Enter the Subject 2 marks:"))
sub3=int(input("Enter the Subject 3 marks:"))
sub4=int(input("Enter the Subject 4 marks:"))
total=sub1+sub2+sub3+sub4
average=total/4
print("Student Name:",last_name,first_name)
print("Subject 1:",sub1)
print("Subject 2:",sub2)
print("Subject 3:",sub3)
print("Subject 4:",sub4)
print("Total:",total)
print("Average:",average)
# Out:
# Enter the First Name: Sabisha
# Enter the Last Name: Suthakaran
# Enter the Subject 1 marks: 90
# Enter the Subject 2 marks: 85
# Enter the Subject 3 marks: 89
# Enter the Subject 4 marks: 95
# Student Name: Suthakaran Sabisha
# Subject 1: 90
# Subject 2: 85
# Subject 3: 89
# Subject 4: 95
# Total: 359
# Average: 89.75

# %%
first_name=input("Enter the First Name:")
last_name=input("Enter the Last Name:")
sub1=int(input("Enter the Subject 1 marks:"))
sub2=int(input("Enter the Subject 2 marks:"))
sub3=int(input("Enter the Subject 3 marks:"))
sub4=int(input("Enter the Subject 4 marks:"))
total=sub1+sub2+sub3+sub4
average=total/4
print("Student Name:",last_name,first_name,",","Subject 1:",sub1,",","Subject 2:",sub2,",","Subject 3:",sub3,",","Subject 4:",sub4,",","Total:",total,",","Average:",average)
# Out:
# Enter the First Name: Sabisha
# Enter the Last Name: Suthakaran
# Enter the Subject 1 marks: 90
# Enter the Subject 2 marks: 85
# Enter the Subject 3 marks: 89
# Enter the Subject 4 marks: 95
# Student Name: Suthakaran Sabisha , Subject 1: 90 , Subject 2: 85 , Subject 3: 89 , Subject 4: 95 , Total: 359 , Average: 89.75
